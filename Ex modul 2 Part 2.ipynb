# %%
import pandas as pn

# %%
df=pn.read_csv('DelayedFlights.csv')

# %%
df.describe()
# Out:
#          Unnamed: 0       Year         Month    DayofMonth     DayOfWeek  \
# count  1.936758e+06  1936758.0  1.936758e+06  1.936758e+06  1.936758e+06
# mean   3.341651e+06     2008.0  6.111106e+00  1.575347e+01  3.984827e+00
# std    2.066065e+06        0.0  3.482546e+00  8.776272e+00  1.995966e+00
# min    0.000000e+00     2008.0  1.000000e+00  1.000000e+00  1.000000e+00
# 25%    1.517452e+06     2008.0  3.000000e+00  8.000000e+00  2.000000e+00
# 50%    3.242558e+06     2008.0  6.000000e+00  1.600000e+01  4.000000e+00
# 75%    4.972467e+06     2008.0  9.000000e+00  2.300000e+01  6.000000e+00
# max    7.009727e+06     2008.0  1.200000e+01  3.100000e+01  7.000000e+00
#
#             DepTime    CRSDepTime       ArrTime    CRSArrTime     FlightNum  \
# count  1.936758e+06  1.936758e+06  1.929648e+06  1.936758e+06  1.936758e+06
# mean   1.518534e+03  1.467473e+03  1.610141e+03  1.634225e+03  2.184263e+03
# std    4.504853e+02  4.247668e+02  5.481781e+02  4.646347e+02  1.944702e+03
# ...

# %%
print('Vols més llargs')
df.sort_values('Distance', ascending=False).head()
# Out:
# Vols més llargs
#          Unnamed: 0  Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  \
# 1255581     4200196  2008      7          18          5   2001.0        1955
# 1926346     6979519  2008     12          20          6   2333.0        2055
# 718062      2353671  2008      4          25          5   1345.0        1335
# 1928077     6982535  2008     12          16          2   2135.0        2055
# 173695       566426  2008      1          13          7   1326.0        1320
#
#          ArrTime  CRSArrTime UniqueCarrier  ...  TaxiIn TaxiOut  Cancelled  \
# 1255581   1126.0        1130            CO  ...     8.0    14.0          0
# 1926346   1348.0        1120            CO  ...    11.0    16.0          0
# 718062    1826.0        1810            CO  ...     4.0    17.0          0
# 1928077   1148.0        1120            CO  ...    13.0    17.0          0
# 173695    1912.0        1920            CO  ...    10.0    15.0          0
#
# ...

# %% [markdown]
# EXERCICI 2

# %%
endarreriments = df.groupby('UniqueCarrier')['ArrDelay'].sum()

print(endarreriments.sort_values(ascending=False))
# Out:
# UniqueCarrier
# WN    11319092.0
# AA     8889066.0
# UA     6733013.0
# MQ     6396704.0
# OO     5978936.0
# XE     5176042.0
# DL     4535644.0
# CO     4045932.0
# EV     3888131.0
# YV     3691461.0
# US     3571867.0
# NW     3462075.0
# FL     3100150.0
# B6     3025749.0
# OH     2675993.0
# 9E     2420468.0
# AS     1406735.0
# F9      788549.0
# HA      255613.0
# AQ       15814.0
# Name: ArrDelay, dtype: float64

# %%
print(df[['Year', 'Month', 'DayofMonth', 'DayOfWeek', 'DepTime', 'ArrTime', 'UniqueCarrier', 'FlightNum', 'Origin', 'Dest', 'Distance']].describe())
# Out:
#             Year         Month    DayofMonth     DayOfWeek       DepTime  \
# count  1936758.0  1.936758e+06  1.936758e+06  1.936758e+06  1.936758e+06
# mean      2008.0  6.111106e+00  1.575347e+01  3.984827e+00  1.518534e+03
# std          0.0  3.482546e+00  8.776272e+00  1.995966e+00  4.504853e+02
# min       2008.0  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# 25%       2008.0  3.000000e+00  8.000000e+00  2.000000e+00  1.203000e+03
# 50%       2008.0  6.000000e+00  1.600000e+01  4.000000e+00  1.545000e+03
# 75%       2008.0  9.000000e+00  2.300000e+01  6.000000e+00  1.900000e+03
# max       2008.0  1.200000e+01  3.100000e+01  7.000000e+00  2.400000e+03
#
#             ArrTime     FlightNum      Distance
# count  1.929648e+06  1.936758e+06  1.936758e+06
# mean   1.610141e+03  2.184263e+03  7.656862e+02
# std    5.481781e+02  1.944702e+03  5.744797e+02
# min    1.000000e+00  1.000000e+00  1.100000e+01
# 25%    1.316000e+03  6.100000e+02  3.380000e+02
# ...

# %%
distancia = df.groupby('Distance')['ArrDelay'].mean()

distancia
# Out:
# Distance
# 11      100.000000
# 24       84.000000
# 30       35.750000
# 31       44.896396
# 35       14.000000
#            ...
# 4184     28.310811
# 4213     42.083333
# 4243     38.350168
# 4502     36.021882
# 4962     32.220497
# Name: ArrDelay, Length: 1419, dtype: float64

# %% [markdown]
# EXERCICI 3
